# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')



data = pd.read_csv('../data/sales_predictions.csv')
data[:]
data.describe()
sb.relplot(x="item_cnt_day", y="item_price", kind="line", data=data)
